# %%
import itertools

# %%
# Example 1 - Range()
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Example 2 - Iterate List
fruits = ['Apple', 'Banana', 'Orange']
for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Banana
# Orange

# %%
# Example 3 - Iterate dictionary
person = {'name':'Alice', 'age': 30}
for key in person:
    print(key, person[key])
# Out:
# name Alice
# age 30

# %%
# Example 4 - Enumerate()
for index, fruit in enumerate(fruits):
    print(index, fruit)
# Out:
# 0 Apple
# 1 Banana
# 2 Orange

# %%
# Example 5 - Zip()
names   = ['Alice', 'Bob', 'Charles']
ages    = [30, 20, 50]
for name, age in zip(names, ages):
    print(name, ages)
# Out:
# Alice [30, 20, 50]
# Bob [30, 20, 50]
# Charles [30, 20, 50]

# %%
# Example 6 - Itertools
for i in itertools.count(start=10, step=2):
    if i > 20:
        break
    print(i)
# Out:
# 10
# 12
# 14
# 16
# 18
# 20
