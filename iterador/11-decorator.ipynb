# %% [markdown]
# Decorator
# - Modify or extend (extend = ampliar/estender) the behavior of existing functions in a reusable way.
# - Add functionality to existing functions without modifying (without changing) their code

# %%
from decorator import my_decorator
